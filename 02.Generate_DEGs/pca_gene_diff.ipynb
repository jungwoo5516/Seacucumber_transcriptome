# %%
import pandas as pd

# %%
df = pd.read_csv("../cuffdiff/gene_exp.diff", delimiter='\t')
df
# Out:
#              test_id      gene_id                       gene  \
# 0        XLOC_000001  XLOC_000001     evm.TU.AJAPscaffold1.1
# 1        XLOC_000002  XLOC_000002     evm.TU.AJAPscaffold1.2
# 2        XLOC_000003  XLOC_000003     evm.TU.AJAPscaffold1.3
# 3        XLOC_000004  XLOC_000004     evm.TU.AJAPscaffold1.4
# 4        XLOC_000005  XLOC_000005     evm.TU.AJAPscaffold1.5
# ...              ...          ...                        ...
# 3748075  XLOC_035692  XLOC_035692  evm.TU.AJAPscaffold999.13
# 3748076  XLOC_035693  XLOC_035693   evm.TU.AJAPscaffold999.4
# 3748077  XLOC_035694  XLOC_035694   evm.TU.AJAPscaffold999.8
# 3748078  XLOC_035695  XLOC_035695  evm.TU.AJAPscaffold999.14
# 3748079  XLOC_035696  XLOC_035696  evm.TU.AJAPscaffold999.15
#
#                                  locus sample_1 sample_2  status    value_1  \
# 0             AJAPscaffold1:5166-13786       BI       BM  NOTEST   0.000000
# 1            AJAPscaffold1:47719-63453       BI       BM  NOTEST   0.000000
# ...

# %%
test_df = df[['gene','sample_1','sample_2','value_1','value_2','significant']]
test_df
test_df.to_csv("gene_exp_spliced_diff2.csv")

# %%
gene_exp_spliced_diff = pd.read_csv("./gene_exp_spliced_diff.csv")

# %%
gene_exp_spliced_diff = gene_exp_spliced_diff.drop(['Unnamed: 0'],axis=1)
gene_exp_spliced_diff
# Out:
#              gene_id sample_1 sample_2    value_1   value_2 significant
# 0        XLOC_000001       BI       BM   0.000000  0.000000          no
# 1        XLOC_000002       BI       BM   0.000000  0.000000          no
# 2        XLOC_000003       BI       BM   0.000000  0.000000          no
# 3        XLOC_000004       BI       BM   0.000000  0.000000          no
# 4        XLOC_000005       BI       BM   0.000000  0.000000          no
# ...              ...      ...      ...        ...       ...         ...
# 3748075  XLOC_035692       RT       RW   0.000000  0.202227          no
# 3748076  XLOC_035693       RT       RW  10.336300  9.095110          no
# 3748077  XLOC_035694       RT       RW   0.000000  0.638801          no
# 3748078  XLOC_035695       RT       RW   0.745572  0.569140          no
# 3748079  XLOC_035696       RT       RW   1.776790  1.434200          no
#
# [3748080 rows x 6 columns]
